# %%
from gradio_client import Client
import json

# %%
client = Client("https://napatswift-test.hf.space/")
# Out:
# Loaded as API: https://napatswift-test.hf.space/ ✔

# %%
r = client.predict('Screenshot 2566-05-11 at 18.30.55.png', api_name="/predict")

# %%
with open(r,) as fp:
  data = json.load(fp)

# %%
polygons = data['predictions'][0]['det_polygons']

# %%
polygons[0]
# Out:
# [125.51445086705202,
#  553.1521739130435,
#  131.6,
#  553.1521739130435,
#  131.6,
#  556.9565217391305,
#  125.51445086705202,
#  556.9565217391305]

# %%
def get_x_y_w_h(polygon: list):
  """Get x, y, w, h from polygon

  Args:
      polygon (list): [x0, y0, x1, y1, ..., xn, yn]
  """
  x_pos = []
  y_pos = []
  for i, pos in enumerate(polygon):
    if i % 2 == 0:
      x_pos.append(pos)
    else:
      y_pos.append(pos)
  
  x = min(x_pos)
  y = min(y_pos)
  w = max(x_pos) - x
  h = max(y_pos) - y
  return dict(x=x, y=y, width=w, height=h)

# %%
[get_x_y_w_h(polygon) for polygon in polygons]
# Out:
# [{'x': 125.51445086705202,
#   'y': 553.1521739130435,
#   'width': 6.085549132947975,
#   'height': 3.804347826086996},
#  {'x': 23.35473032604063,
#   'y': 546.5096117102582,
#   'width': 27.122317579853743,
#   'height': 9.978889797044758},
#  {'x': 22.820809248554912,
#   'y': 521.9565217391305,
#   'width': 23.581502890173407,
#   'height': 8.369565217391255},
#  {'x': 354.01109993113255,
#   'y': 509.36279296875006,
#   'width': 16.13196097136921,
#   'height': 16.37179167374319},
#  {'x': 62.32968347803016,
#   'y': 505.9976727029552,
#   'width': 283.0680606202583,
#   'height': 22.062895401664434},
#  {'x': 21.77239330049195,
#   'y': 501.6275024414063,
#   'width': 33.98015601097504,
#   'height': 17.439814028532567},
#  {'x': 23.73365235521614,
#   'y': 478.89132292374325,
#   'width': 9.73687948326155,
#   'height': 7.304329250169815},
#  {'x': 356.0046242774566,
#   'y': 467.9347826086957,
#   'width': 12.171098265895978,
#   'height': 11.413043478260875},
# ...

# %%
import requests
import os

# %%
def get_tasks(page=1, page_size=100):
  resp = requests.get('https://labelstudio.wevis.info/api/projects/1/tasks',
                     params={'page': page, 'page_size': page_size},
                     headers={'Authorization': 'Token e5f1ba3ecc0d6d5424d94f319fddc133dee895a5'})
  if resp.ok:
    return resp.json()
  return []

def delete_task(task_id):
  resp = requests.delete('https://labelstudio.wevis.info/api/tasks/%s' % task_id,
                     headers={'Authorization': 'Token e5f1ba3ecc0d6d5424d94f319fddc133dee895a5'})
  return resp.status_code == 204

# %%
image_vote_count = os.listdir('../vote62/data/image/1/') # class 1 is the vote count paper

def delete_tasks(task_list):
    found = 0
    for task in task_list:
        try:
            image_name = task['data']['image'].split('/')[-1]
        except TypeError:
            continue
        # If image is not in vote count paper, delete it
        if image_name in image_vote_count:
            found += 1
        else:
            if delete_task(task['id']):
                print('Deleted %s' % task['id'])
            else:
                print('Cannot delete %s' % task['id'])
    return found

# %%
page_i = 1
tasks = get_tasks(page=page_i)
while len(tasks) > 0:
    delete_tasks(tasks)
    print(f'Page {page_i} has {len(tasks)} tasks')
    page_i += 1
    tasks = get_tasks(page=page_i)
# Out:
# Deleted 13798
# Deleted 13796
# Deleted 13795
# Deleted 13794
# Deleted 13793
# Deleted 13791
# Deleted 13790
# Deleted 13787
# Deleted 13786
# Deleted 13781
# Deleted 13780
# Deleted 13779
# Deleted 13777
# Deleted 13776
# Deleted 13775
# Deleted 13774
# Deleted 13773
# Deleted 13772
# Deleted 13771
# Deleted 13768
# Deleted 13766
# Deleted 13765
# Deleted 13763
# Deleted 13762
# Deleted 13760
# Deleted 13759
# Deleted 13756
# Deleted 13755
# Deleted 13754
# Deleted 13753
# Deleted 13752
# Deleted 13746
# Deleted 13745
# Deleted 13739
# Deleted 13738
# Deleted 13737
# Deleted 13735
# Deleted 13734
# Deleted 13732
# Deleted 13731
# Deleted 13730
# Deleted 13729
# Deleted 13728
# Page 66 has 100 tasks
# Deleted 13665
# Deleted 13662
# Deleted 13661
# Deleted 13659
# Deleted 13658
# Deleted 13657
# Deleted 13654
# Deleted 13650
# Deleted 13647
# Deleted 13646
# Deleted 13643
# Deleted 13640
# Deleted 13638
# Deleted 13636
# Deleted 13635
# Deleted 13633
# Deleted 13631
# Deleted 13630
# ...

# %%
image_vote_count = os.listdir('../vote62/data/image/1/')

# %%
get_tasks(page=999)
# Out:
# []
